# %% [markdown]
# ## imports

# %%
import asyncio
import json
import random
from dataclasses import dataclass
from typing import Optional
import art
from src.state_extractor import StateExtractor
from src.courtroom_env import CourtroomEnv, RoleAssignment
from src.llm_judge import LLMJudge
from data.load_data import TrainingQuery

# %% [markdown]
# ## Configuration
